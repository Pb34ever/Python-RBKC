# %%
import pandas as pd

# %%
filepath1 = r"https://raw.githubusercontent.com/data-to-insight/ERN-sessions/main/data/1980%202023%20average%20house%20prices.csv"

df = pd.read_csv(filepath1)

df
# Out:
#                Name   Period  House price index All property types  \
# 0    United Kingdom  1980-01                                 10.11
# 1    United Kingdom  1980-02                                 10.11
# 2    United Kingdom  1980-03                                 10.11
# 3    United Kingdom  1980-04                                 10.51
# 4    United Kingdom  1980-05                                 10.51
# ..              ...      ...                                   ...
# 518  United Kingdom  2023-03                                148.20
# 519  United Kingdom  2023-04                                148.90
# 520  United Kingdom  2023-05                                149.50
# 521  United Kingdom  2023-06                                151.20
# 522  United Kingdom  2023-07                                152.00
#
#      Average price All property types  \
# 0                               19273
# 1                               19273
# 2                               19273
# ...

# %%
df.info()
df.head()
df.tail()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 523 entries, 0 to 522
# Data columns (total 6 columns):
#  #   Column                                          Non-Null Count  Dtype
# ---  ------                                          --------------  -----
#  0   Name                                            523 non-null    object
#  1   Period                                          523 non-null    object
#  2   House price index All property types            523 non-null    float64
#  3   Average price All property types                523 non-null    int64
#  4   Percentage change (monthly) All property types  523 non-null    float64
#  5   Percentage change (yearly) All property types   523 non-null    float64
# dtypes: float64(3), int64(1), object(2)
# memory usage: 24.6+ KB
#                Name   Period  House price index All property types  \
# 518  United Kingdom  2023-03                                 148.2
# ...

# %%
filepath1 = R"https://raw.githubusercontent.com/data-to-insight/ERN-sessions/main/data/ChildIdentifiers.csv"

df2 = pd.read_csv(filepath1)

df2.info()
df2.head()
df2.tail()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[5], line 3
#       1 filepath1 = R"https://raw.githubusercontent.com/data-to-insight/ERN-sessions/main/data/ChildIdentifiers.csv"
# ----> 3 df2 = pd.read_csv(filepath1)
#       5 df2.info()
#       6 df2.head()
#
# NameError: name 'pd' is not defined

# %%
df = pd.read_csv(filepath)

df.info()
df.head()
df.tail()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 332 entries, 0 to 331
# Data columns (total 9 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Unnamed: 0               332 non-null    int64
#  1   LAchildID                332 non-null    object
#  2   UPN                      332 non-null    object
#  3   FormerUPN                0 non-null      float64
#  4   UPNunknown               0 non-null      float64
#  5   PersonBirthDate          332 non-null    object
#  6   ExpectedPersonBirthDate  7 non-null      object
#  7   GenderCurrent            332 non-null    int64
#  8   PersonDeathDate          21 non-null     object
# dtypes: float64(2), int64(2), object(5)
# memory usage: 23.5+ KB
#      Unnamed: 0        LAchildID            UPN  FormerUPN  UPNunknown  \
# 327         327  RND000112711501  A465246916125        NaN         NaN
# ...

# %%
df['Period'] = pd.to_datetime(df['Period'],  format="%Y-%m")

df.info
# Out:
# <bound method DataFrame.info of                Name     Period  House price index All property types  \
# 0    United Kingdom 1980-01-01                                 10.11
# 1    United Kingdom 1980-02-01                                 10.11
# 2    United Kingdom 1980-03-01                                 10.11
# 3    United Kingdom 1980-04-01                                 10.51
# 4    United Kingdom 1980-05-01                                 10.51
# ..              ...        ...                                   ...
# 518  United Kingdom 2023-03-01                                148.20
# 519  United Kingdom 2023-04-01                                148.90
# 520  United Kingdom 2023-05-01                                149.50
# 521  United Kingdom 2023-06-01                                151.20
# 522  United Kingdom 2023-07-01                                152.00
#
#      Average price All property types  \
# 0                               19273
# ...

# %%
df['Period'] = pd.to_datetime(df['Period'],  format="%D/%m")

df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 523 entries, 0 to 522
# Data columns (total 6 columns):
#  #   Column                                          Non-Null Count  Dtype
# ---  ------                                          --------------  -----
#  0   Name                                            523 non-null    object
#  1   Period                                          523 non-null    datetime64[ns]
#  2   House price index All property types            523 non-null    float64
#  3   Average price All property types                523 non-null    int64
#  4   Percentage change (monthly) All property types  523 non-null    float64
#  5   Percentage change (yearly) All property types   523 non-null    float64
# dtypes: datetime64[ns](1), float64(3), int64(1), object(1)
# memory usage: 24.6+ KB

# %%
df_sum = df["Average price All property types"].sum() 

print(df_sum)

df.info()
# Out:
# 63058402
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 523 entries, 0 to 522
# Data columns (total 6 columns):
#  #   Column                                          Non-Null Count  Dtype
# ---  ------                                          --------------  -----
#  0   Name                                            523 non-null    object
#  1   Period                                          523 non-null    datetime64[ns]
#  2   House price index All property types            523 non-null    float64
#  3   Average price All property types                523 non-null    int64
#  4   Percentage change (monthly) All property types  523 non-null    float64
#  5   Percentage change (yearly) All property types   523 non-null    float64
# dtypes: datetime64[ns](1), float64(3), int64(1), object(1)
# memory usage: 24.6+ KB

# %%
df1 = R"https://raw.githubusercontent.com/data-to-insight/ERN-sessions/main/data/ChildIdentifiers.csv"
df1 = pd.read_csv(df1)
df1.info
df1.head()
# Out:
#    Unnamed: 0        LAchildID            UPN  FormerUPN  UPNunknown  \
# 0           0  RND000215205141  A850728973744        NaN         NaN
# 1           1  RND000824303014  A141396438491        NaN         NaN
# 2           2  RND000750143123  A929946861554        NaN         NaN
# 3           3  RND000909164501  A612330267292        NaN         NaN
# 4           4  RND000382171815  A604459366806        NaN         NaN
#
#   PersonBirthDate ExpectedPersonBirthDate  GenderCurrent PersonDeathDate
# 0      2019-12-06                     NaN              1             NaN
# 1      2011-04-27                     NaN              9             NaN
# 2      2017-06-06              2019-12-06              1             NaN
# 3      2014-10-03                     NaN              0             NaN
# 4      2019-09-25                     NaN              2             NaN

# %%
df1['Period'] = pd.to_datetime(df1['Period'], format="%Y-%m")

df1['PersonBirthDate'] = pd.to_datetime(df1['PersonBirthDate'], format="%Y-%m-%d")

df1.info()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~/.local/lib/python3.10/site-packages/pandas/core/indexes/base.py:3805, in Index.get_loc(self, key)
#    3804 try:
# -> 3805     return self._engine.get_loc(casted_key)
#    3806 except KeyError as err:
#
# File index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:7081, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:7089, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Period'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[62], line 1
# ----> 1 df1['Period'] = pd.to_datetime(df1['Period'], format="%Y-%m")
# ...

# %%
df1['Period'] = pd.to_datetime(df1['Period'], format="%Y-%m")

df1['PersonBirthDate'] = pd.to_datetime(df1['PersonBirthDate'], format="%Y-%m-%d")
df1['ExpectedPersonBirthDate'] = pd.to_datetime(df1['ExpectedPersonBirthDate'], format="%Y-%m-%d")

df1.info()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~/.local/lib/python3.10/site-packages/pandas/core/indexes/base.py:3805, in Index.get_loc(self, key)
#    3804 try:
# -> 3805     return self._engine.get_loc(casted_key)
#    3806 except KeyError as err:
#
# File index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:7081, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:7089, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Period'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[59], line 1
# ----> 1 df1['Period'] = pd.to_datetime(df1['Period'], format="%Y-%m")
# ...

# %%
df1.info()
df1.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 332 entries, 0 to 331
# Data columns (total 9 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Unnamed: 0               332 non-null    int64
#  1   LAchildID                332 non-null    object
#  2   UPN                      332 non-null    object
#  3   FormerUPN                0 non-null      float64
#  4   UPNunknown               0 non-null      float64
#  5   PersonBirthDate          332 non-null    object
#  6   ExpectedPersonBirthDate  7 non-null      object
#  7   GenderCurrent            332 non-null    int64
#  8   PersonDeathDate          21 non-null     object
# dtypes: float64(2), int64(2), object(5)
# memory usage: 23.5+ KB
#    Unnamed: 0        LAchildID            UPN  FormerUPN  UPNunknown  \
# 0           0  RND000215205141  A850728973744        NaN         NaN
# 1           1  RND000824303014  A141396438491        NaN         NaN
# ...

# %%
df1["Age"] = pd.to_datetime("01/04/2024", format="%d/%m/%Y") - df1['PersonBirthDate']

df1["Age"] / pd.Timedelta(365.25, "d")

df1["Age"]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[64], line 1
# ----> 1 df1["Age"] = pd.to_datetime("01/04/2024", format="%d/%m/%Y") - df1['PersonBirthDate']
#       3 df1["Age"] / pd.Timedelta(365.25, "d")
#       5 df1["Age"]
#
# File ~/.local/lib/python3.10/site-packages/pandas/core/ops/common.py:76, in _unpack_zerodim_and_defer.<locals>.new_method(self, other)
#      72             return NotImplemented
#      74 other = item_from_zerodim(other)
# ---> 76 return method(self, other)
#
# File ~/.local/lib/python3.10/site-packages/pandas/core/arraylike.py:198, in OpsMixin.__rsub__(self, other)
#     196 @unpack_zerodim_and_defer("__rsub__")
#     197 def __rsub__(self, other):
# --> 198     return self._arith_method(other, roperator.rsub)
#
# File ~/.local/lib/python3.10/site-packages/pandas/core/series.py:6126, in Series._arith_method(self, other, op)
# ...

# %%
df1['Age'] = pd.to_datetime("01/04/24", format="%d/%m/%y") - df1['PersonBirthDate']
df1['Age'] = df1['Age'] / pd.Timedelta(365.25, "d")
df1["Age"] = df1["Age"].astype('int')
 
df1
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[66], line 1
# ----> 1 df1['Age'] = pd.to_datetime("01/04/24", format="%d/%m/%y") - df1['PersonBirthDate']
#       2 df1['Age'] = df1['Age'] / pd.Timedelta(365.25, "d")
#       3 df1["Age"] = df1["Age"].astype('int')
#
# File ~/.local/lib/python3.10/site-packages/pandas/core/ops/common.py:76, in _unpack_zerodim_and_defer.<locals>.new_method(self, other)
#      72             return NotImplemented
#      74 other = item_from_zerodim(other)
# ---> 76 return method(self, other)
#
# File ~/.local/lib/python3.10/site-packages/pandas/core/arraylike.py:198, in OpsMixin.__rsub__(self, other)
#     196 @unpack_zerodim_and_defer("__rsub__")
#     197 def __rsub__(self, other):
# --> 198     return self._arith_method(other, roperator.rsub)
#
# ...

# %%
above_average_price = df["Average price All property types"] > df['Average price All property types'].mean()

above_average_price
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 518     True
# 519     True
# 520     True
# 521     True
# 522     True
# Name: Average price All property types, Length: 523, dtype: bool

# %%
above_average_price = df['Average price All property types'] > df['Average price All property types'].mean()

above_av_df = df[above_average_price]
above_av_df
# Out:
#                Name     Period  House price index All property types  \
# 274  United Kingdom 2002-11-01                                 63.83
# 275  United Kingdom 2002-12-01                                 65.95
# 276  United Kingdom 2003-01-01                                 65.47
# 277  United Kingdom 2003-02-01                                 64.78
# 278  United Kingdom 2003-03-01                                 66.16
# ..              ...        ...                                   ...
# 518  United Kingdom 2023-03-01                                148.20
# 519  United Kingdom 2023-04-01                                148.90
# 520  United Kingdom 2023-05-01                                149.50
# 521  United Kingdom 2023-06-01                                151.20
# 522  United Kingdom 2023-07-01                                152.00
#
#      Average price All property types  \
# 274                            121700
# 275                            125747
# ...
